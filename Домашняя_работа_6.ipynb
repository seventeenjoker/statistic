# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks): zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110], ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832].
# а) Найдите ковариацию этих двух величин с помощью элементарных действий, а затем с помощью функции cov из numpy
# Полученные значения должны быть равны.
# б) Найдите коэффициент корреляции Пирсона с помощью ковариации и среднеквадратичных отклонений двух признаков,
# а затем с использованием функций из библиотек numpy и pandas.

# %%
zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110]
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
cov = np.mean(zp*ks) - np.mean(zp)*np.mean(ks)
cov
# Out:
# 9157.839999999997

# %%
np.cov(zp, ks, ddof=0)
# Out:
# array([[ 3494.64,  9157.84],
#        [ 9157.84, 30468.89]])

# %%
9157.84 == 9157.84
# Out:
# True

# %% [markdown]
# Зная ковариацию и среднее квадратичное отклонение каждого из двух
# признаков, можно вычислить коэффициент корреляции Пирсона:
# ![Pirson.png](attachment:Pirson.png)

# %%
# Среднеквадратичное отклонение для зарплаты:
np.std(zp)
# Out:
# 59.115480206118605

# %%
# Среднеквадратичное отклонение для поведенческого кредитного скоринга 
np.std(ks)
# Out:
# 174.55340157098058

# %%
9157.84/(59.16*174.55)
# Out:
# 0.886839509458205

# %%
np.corrcoef(zp, ks)[0, 1]
# Out:
# 0.8874900920739162

# %%
pd.DataFrame(zip(zp, ks), columns=['zp', 'ks']).corr().loc['zp', 'ks']
# Out:
# 0.8874900920739162

# %%
0.89 == 0.89
# Out:
# True

# %% [markdown]
# **Ответ:** ковариация заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга равна 9157.84; коэффициент корреляции Пирсона равен 0.89.

# %% [markdown]
# ### 2. Измерены значения IQ выборки студентов, обучающихся в местных технических вузах: 131, 125, 115, 122, 131, 115, 107, 99, 125, 111. Известно, что в генеральной совокупности IQ распределен нормально. Найдите доверительный интервал для математического ожидания с надежностью 0.95.

# %%
iq = [131, 125, 115, 122, 131, 115, 107, 99, 125, 111]

# %%
# средняя
mean = np.mean(iq)
mean
# Out:
# 118.1

# %%
# объем выборки 
n = len(iq)
n
# Out:
# 10

# %%
# среднеквадратичное отклонение
mu = np.std(iq, ddof=1)
mu
# Out:
# 10.54566788359614

# %%
# критерий Стьюдента = 2,262
# Тогда интервал:
print(f"{np.mean(iq)-2.262*np.std(iq, ddof=1)/len(iq)**(0.5):.4f}, {np.mean(iq)+2.262*np.std(iq, ddof=1)/len(iq)**(0.5):.4f}")
# Out:
# 110.5566, 125.6434

# %% [markdown]
# **Ответ:** доверительный интервал для математического ожидания с надежностью 0.95: [110.5566, 125.6434]

# %% [markdown]
# ### 3. Известно, что рост футболистов в сборной распределен нормально с дисперсией генеральной совокупности, равной 25 кв.см. Объем выборки равен 27, среднее выборочное составляет 174.2. Найдите доверительный интервал для математического ожидания с надежностью 0.95.

# %%
print(f'T(0.95) = [{174.2-1.96*np.sqrt(25)/np.sqrt(27):.2f}, {174.2+1.96*np.sqrt(25)/np.sqrt(27):.2f}]')
# Out:
# T(0.95) = [172.31, 176.09]

# %% [markdown]
# **Ответ:** доверительный интервал для математического ожидания с надежностью 0.95: [172.31, 176.09]
